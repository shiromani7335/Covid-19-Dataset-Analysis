# %% [markdown]
# # Covid-19 Dataset

# %% [markdown]
# * We have taken a small dataset of Covid-19, just for your understanding purpose. You have to work on the original dataset which contains about 19000 rows.
# * The data used here is till 29-April-2020.
# * This data is avaliable as a CSV file. downloaded from Kaggle.
# * We will analyze this data using the Pandas DataFrame

# %% [markdown]
# The commands that we used in this project :
#
# * import pandas as pd -- To import Pandas library
# * pd.read_csv - To import the CSV file in Jupyter notebook
# * df.count() - It counts the no. of non-null values of each column.
# * df.isnull().sum() - It detects the missing values from the dataframe.
# * import seaborn as sns - To import the Seaborn library.
# * import matplotlib.pyplot as plt - To import the Matplotlib library.
# * sns.heatmap(df.isnull()) - It will show the all columns & missing values in them in heat map form.
# * plt.show() - To show the plot.
# * df.groupby(‘Col_name’) - To form groups of all unique values of the column.
# * df.sort_values(by= ['Col_name'] ) - Sort the entire dataframe by the values of the given column.
# * df[df.Col_1 = = ‘Element1’] - Filtering – We are accessing all records with Element1 only of Col_1.

# %%
import pandas as pd

# %%
covid=pd.read_csv(r"H:\Jupyter lab programm\Data analytics project\Project 4. Covid_19_data\4. covid_19_data.csv")
covid
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covid.count()     # for not null values
# null values means missing values
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
covid.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
# to see the results in form of not null values or null values in the form of heatmap

# %%
sbn.heatmap(covid.isnull())
plt.show()

# %% [markdown]
# the white part is showing null values present in state column

# %% [markdown]
# # 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
#  1) Show the number of Confirmed in each Region.

# %%
covid.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)       # for desending order on behalf of numertic values
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# 2) Show the number of Deaths cases in each Region.

# %%
covid.groupby('Region')['Deaths'].sum().sort_values(ascending=False)
# Out:
# Region
# US             60967
# Italy          27682
# UK             26166
# Spain          24275
# France         24121
#                ...
# Holy See           0
# Grenada            0
# South Sudan        0
# Nepal              0
# Laos               0
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# 3) Show the number of Recovered cases in each Region.

# %%
covid.groupby('Region')['Recovered'].sum().sort_values(ascending=True)
# Out:
# Region
# Papua New Guinea         0
# South Sudan              0
# MS Zaandam               0
# Yemen                    1
# Cabo Verde               2
#                      ...
# Iran                 73791
# Mainland China       77610
# Germany             120400
# US                  120720
# Spain               132929
# Name: Recovered, Length: 187, dtype: int64

# %% [markdown]
#  for more than one column

# %%
covid.groupby('Region')['Confirmed','Recovered'].sum()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_23656\1839298319.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   covid.groupby('Region')['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# # 2) Remove all the records where the Confirmed Cases is Less Than 10.

# %%
# df.Confirmed<10
# df[df.Confirmed<10]
# df~[df.Confirmed<10]
# df=df~[df.Confirmed<10]
covid.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid[covid.Confirmed<10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
covid[~(covid.Confirmed<10)]     #To remove the all records satisfying a particular conditon
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
# covid

# %% [markdown]
# # 3) In which Region, maximum number of Confirmed cases were recorded ?

# %%
# df.groupby("Region").Confirmed.sum().sort_values(ascending=FFalse)

# %%
covid.groupby('Region').Confirmed.sum().sort_values(ascending=False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(20)        # For the top 20 rows/Values/records
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# # 4) In which Region, minimum number of Deaths cases were recorded ?

# %%
covid.groupby('Region').Confirmed.sum().sort_values(ascending=True)        # minimum>>>>>>> descending order
# Out:
# Region
# Yemen                          6
# Western Sahara                 6
# Bhutan                         7
# Papua New Guinea               8
# Sao Tome and Principe          8
#                           ...
# UK                        166441
# France                    166543
# Italy                     203591
# Spain                     236899
# US                       1039909
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid.groupby('Region').Confirmed.sum().sort_values(ascending=True).head(10)              # For top 10 minimum number of Deaths cases were recorded
# Out:
# Region
# Yemen                     6
# Western Sahara            6
# Bhutan                    7
# Papua New Guinea          8
# Sao Tome and Principe     8
# Mauritania                8
# MS Zaandam                9
# Gambia                   10
# Holy See                 10
# Suriname                 10
# Name: Confirmed, dtype: int64

# %% [markdown]
# # 5) How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
# df[df.Region=='Country_name']             >>>>>>>>> filtering

# %%
covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
covid[covid.Region=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
# covid[covid.Region=='Saudi Arabia']        # for another country like Saudi Arabia

# %%
# covid[covid.Region=='US']

# %% [markdown]
# # 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
# df.sort_values(by=['Confirmed'], ascending=True)

# %%
covid.sort_values(by=['Confirmed'],ascending=True)
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %%
#covid.sort_values(by=['Confirmed'],ascending=True).head(15)     # for top 15 records

# %% [markdown]
# # 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
#covid.sort_values(by=['Recovered'])       # by default ascending

# %%
covid.sort_values(by=['Recovered'],ascending=False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]

# %%
covid.sort_values(by=['Recovered'],ascending=False).head(30)
# Out:
#           Date      State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020        NaN           Spain     236899   24275     132929
# 285  4/29/2020  Recovered              US          0       0     120720
# 61   4/29/2020        NaN         Germany     161539    6467     120400
# 76   4/29/2020        NaN            Iran      93657    5957      73791
# 80   4/29/2020        NaN           Italy     203591   27682      71252
# 229  4/29/2020      Hubei  Mainland China      68128    4512      63616
# 57   4/29/2020        NaN          France     165093   24087      48228
# 167  4/29/2020        NaN          Turkey     117589    3081      44040
# 22   4/29/2020        NaN          Brazil      79685    5513      34132
# 158  4/29/2020        NaN     Switzerland      29407    1716      22600
# 284  4/29/2020  Recovered          Canada          0       0      20327
# 78   4/29/2020        NaN         Ireland      20253    1190      13386
# ...
